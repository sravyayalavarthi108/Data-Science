# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
movies = pd.read_csv('Movie-Rating.csv')

# %%
movies
# Out:
#                       Film      Genre  Rotten Tomatoes Ratings %  \
# 0    (500) Days of Summer      Comedy                         87
# 1              10,000 B.C.  Adventure                          9
# 2               12 Rounds      Action                         30
# 3                127 Hours  Adventure                         93
# 4                17 Again      Comedy                         55
# ..                     ...        ...                        ...
# 554          Your Highness     Comedy                         26
# 555        Youth in Revolt     Comedy                         68
# 556                 Zodiac   Thriller                         89
# 557            Zombieland      Action                         90
# 558              Zookeeper     Comedy                         14
#
#      Audience Ratings %  Budget (million $)  Year of release
# 0                    81                   8             2009
# 1                    44                 105             2008
# ...

# %%
len(movies)
# Out:
# 559

# %%
print(np.__version__)
# Out:
# 1.26.4

# %%
print(pd.__version__)
# Out:
# 2.2.2

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Film                       559 non-null    object
#  1   Genre                      559 non-null    object
#  2   Rotten Tomatoes Ratings %  559 non-null    int64
#  3   Audience Ratings %         559 non-null    int64
#  4   Budget (million $)         559 non-null    int64
#  5   Year of release            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.shape
# Out:
# (559, 6)

# %%
movies.head()
# Out:
#                     Film      Genre  Rotten Tomatoes Ratings %  \
# 0  (500) Days of Summer      Comedy                         87
# 1            10,000 B.C.  Adventure                          9
# 2             12 Rounds      Action                         30
# 3              127 Hours  Adventure                         93
# 4              17 Again      Comedy                         55
#
#    Audience Ratings %  Budget (million $)  Year of release
# 0                  81                   8             2009
# 1                  44                 105             2008
# 2                  52                  20             2009
# 3                  84                  18             2010
# 4                  70                  20             2009

# %%
movies.tail()
# Out:
#                 Film     Genre  Rotten Tomatoes Ratings %  Audience Ratings %  \
# 554    Your Highness    Comedy                         26                  36
# 555  Youth in Revolt    Comedy                         68                  52
# 556           Zodiac  Thriller                         89                  73
# 557      Zombieland     Action                         90                  87
# 558        Zookeeper    Comedy                         14                  42
#
#      Budget (million $)  Year of release
# 554                  50             2011
# 555                  18             2009
# 556                  65             2007
# 557                  24             2009
# 558                  80             2011

# %%
movies.columns
# Out:
# Index(['Film', 'Genre', 'Rotten Tomatoes Ratings %', 'Audience Ratings %',
#        'Budget (million $)', 'Year of release'],
#       dtype='object')

# %%
movies.columns=['film','Genre','Criticrating','Audiencerating','Budgetmillions','Year']

# %%
movies.columns
# Out:
# Index(['film', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetmillions',
#        'Year'],
#       dtype='object')

# %%
movies.head(1)
# Out:
#                     film   Genre  Criticrating  Audiencerating  \
# 0  (500) Days of Summer   Comedy            87              81
#
#    Budgetmillions  Year
# 0               8  2009

# %%
movies.describe()
# Out:
#        Criticrating  Audiencerating  Budgetmillions         Year
# count    559.000000      559.000000      559.000000   559.000000
# mean      47.309481       58.744186       50.236136  2009.152057
# std       26.413091       16.826887       48.731817     1.362632
# min        0.000000        0.000000        0.000000  2007.000000
# 25%       25.000000       47.000000       20.000000  2008.000000
# 50%       46.000000       58.000000       35.000000  2009.000000
# 75%       70.000000       72.000000       65.000000  2010.000000
# max       97.000000       96.000000      300.000000  2011.000000

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   film            559 non-null    object
#  1   Genre           559 non-null    object
#  2   Criticrating    559 non-null    int64
#  3   Audiencerating  559 non-null    int64
#  4   Budgetmillions  559 non-null    int64
#  5   Year            559 non-null    int64
# dtypes: int64(4), object(2)
# memory usage: 26.3+ KB

# %%
movies.film = movies.film.astype('category')

# %%
movies. Genre = movies.Genre.astype('category')

# %%
movies.Year = movies.Year.astype('category')

# %%
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 559 entries, 0 to 558
# Data columns (total 6 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   film            559 non-null    category
#  1   Genre           559 non-null    category
#  2   Criticrating    559 non-null    int64
#  3   Audiencerating  559 non-null    int64
#  4   Budgetmillions  559 non-null    int64
#  5   Year            559 non-null    category
# dtypes: category(3), int64(3)
# memory usage: 36.5 KB

# %%
movies.describe()
# Out:
#        Criticrating  Audiencerating  Budgetmillions
# count    559.000000      559.000000      559.000000
# mean      47.309481       58.744186       50.236136
# std       26.413091       16.826887       48.731817
# min        0.000000        0.000000        0.000000
# 25%       25.000000       47.000000       20.000000
# 50%       46.000000       58.000000       35.000000
# 75%       70.000000       72.000000       65.000000
# max       97.000000       96.000000      300.000000

# %%
# %matplotlib inline

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
j = sns.jointplot(data=movies,x='Criticrating',y='Audiencerating')

# %%
j = sns.jointplot(data=movies,x='Criticrating',y='Audiencerating', kind='hex')

# %%
j = sns.jointplot(data=movies,x='Criticrating',y='Audiencerating', kind='kde') # somnemore kind types check

# %%
m1 = sns.distplot(movies.Audiencerating) # distplot=distribution plot

# %%
m1 = sns.displot(movies.Audiencerating) # distplot=distribution plot

# %%
m2 = sns.distplot(movies.Criticrating) # distplot=distribution plot

# %%
sns.set_style('darkgrid') #whitegrid, dark, white, ticks

# %%
m2 = sns.distplot(movies.Criticrating) # distplot=distribution plot

# %%
sns.set_style('white')
m3 = sns.distplot(movies.Criticrating, bins=10) # distplot=distribution plot

# %%
sns.set_style('whitegrid')
m3 = plt.hist(movies.Criticrating, bins=15) # distplot=distribution plot

# %%
plt.hist(movies.Budgetmillions)
# Out:
# (array([237., 162.,  75.,  28.,  17.,  20.,  13.,   3.,   3.,   1.]),
#  array([  0.,  30.,  60.,  90., 120., 150., 180., 210., 240., 270., 300.]),
#  <BarContainer object of 10 artists>)

# %%
vis1 = sns.lmplot(data=movies, x='Criticrating', y='Audiencerating', fit_reg=False, hue='Genre')

# %%
vis1 = sns.lmplot(data=movies, x='Criticrating', y='Audiencerating', fit_reg=True, hue='Genre')

# %%
n1 = plt.hist(movies.Criticrating, bins=10)

# %%
plt.hist(movies.Budgetmillions)
plt.show()

# %%
plt.hist(movies[movies.Genre=='Drama'].Budgetmillions)
# Out:
# (array([25., 40., 18.,  8.,  6.,  2.,  1.,  0.,  0.,  1.]),
#  array([  0.,  15.,  30.,  45.,  60.,  75.,  90., 105., 120., 135., 150.]),
#  <BarContainer object of 10 artists>)

# %%
movies.head()
# Out:
#                     film      Genre  Criticrating  Audiencerating  \
# 0  (500) Days of Summer      Comedy            87              81
# 1            10,000 B.C.  Adventure             9              44
# 2             12 Rounds      Action            30              52
# 3              127 Hours  Adventure            93              84
# 4              17 Again      Comedy            55              70
#
#    Budgetmillions  Year
# 0               8  2009
# 1             105  2008
# 2              20  2009
# 3              18  2010
# 4              20  2009

# %%
plt.hist(movies[movies.Genre=='Action'].Budgetmillions,bins=20)
plt.hist(movies[movies.Genre=='Drama'].Budgetmillions,bins=20)
plt.hist(movies[movies.Genre=='Thriller'].Budgetmillions,bins=20)

#plt.hist(movies[movies.Genre=='Comedy'].Budgetmillions,bins=20)
#plt.hist(movies[movies.Genre=='Romance'].Budgetmillions,bins=20)
plt.legend()
plt.show()

# %%
plt.hist([movies[movies.Genre=='Action'].Budgetmillions,movies[movies.Genre=='Drama'].Budgetmillions,
          movies[movies.Genre=='Thriller'].Budgetmillions,movies[movies.Genre=='Comedy'].Budgetmillions],bins=20,stacked=True)
plt.show()

# %%
for gen in movies.Genre.unique():
    print(gen)
# Out:
# Comedy
# Adventure
# Action
# Horror
# Drama
# Romance
# Thriller

# %%
vis1 = sns.lmplot(data=movies, x='Criticrating', y='Audiencerating', fit_reg=False, hue='Genre')

# %%
vis1 = sns.lmplot(data=movies, x='Criticrating', y='Audiencerating', fit_reg=False, hue='Genre',height=5,aspect=1)

# %%
k1=sns.kdeplot(x=movies.Criticrating,y=movies.Audiencerating)

# %%
k1=sns.kdeplot(x=movies.Criticrating,y=movies.Audiencerating,shade_lowest=True,cmap='Greens_r')

# %%
sns.set_style('dark')
k2=sns.kdeplot(x=movies.Budgetmillions,y=movies.Audiencerating,shade_lowest=False,cmap='Greens_r')

# %%
k3=sns.kdeplot(x=movies.Budgetmillions,y=movies.Criticrating)

# %%
#f,ax= plt.subplots(1,2,figsize=(12,5))
f,ax= plt.subplots(3,3,figsize=(12,5))

# %%
f,ax=plt.subplots(1,2,figsize=(12,5))
k1=sns.kdeplot(x=movies.Budgetmillions, y=movies.Audiencerating,ax=ax[0])
k2=sns.kdeplot(x=movies.Budgetmillions, y=movies.Criticrating,ax=ax[1])

# %%
plt.axes
# Out:
# <function matplotlib.pyplot.axes(arg: 'None | tuple[float, float, float, float]' = None, **kwargs) -> 'matplotlib.axes.Axes'>

# %%
w=sns.boxplot(data=movies,x=movies.Genre, y=movies.Budgetmillions)

# %%
movies.columns
# Out:
# Index(['film', 'Genre', 'Criticrating', 'Audiencerating', 'Budgetmillions',
#        'Year'],
#       dtype='object')

# %%
w1=sns.boxplot(data=movies,x=movies.Genre, y=movies.Criticrating)

# %%
w3=sns.boxplot(data=movies,x=movies.Genre, y=movies.Audiencerating)

# %%
z=sns.violinplot(data=movies,x=movies.Genre,y=movies.Budgetmillions)

# %%
z1=sns.violinplot(data=movies, x=movies.Genre,y=movies.Audiencerating)

# %%
z3=sns.violinplot(data=movies, x=movies.Genre, y=movies.Criticrating)

# %%
w1=sns.boxplot(data=movies[movies.Genre=='Drama'], x=movies.Year,y=movies.Audiencerating)

# %%
z2=sns.violinplot(data=movies[movies.Genre=='Drama'],x=movies.Year,y=movies.Criticrating)

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')

# %%
plt.scatter(movies.Criticrating,movies.Audiencerating)

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.scatter,'Criticrating','Audiencerating')

# %%
g=sns.FacetGrid(movies,row='Genre',col='Year',hue='Genre')
g=g.map(plt.hist,'Budgetmillions')

# %%
g =sns.FacetGrid (movies, row = 'Genre', col = 'Year', hue = 'Genre')
kws=dict(s=50,linewidth=0.7,edgecolor="black")
g=g.map(plt.scatter,'Criticrating','Audiencerating',**kws)

# %%
sns.set_style('darkgrid')
f,axes=plt.subplots(2,2,figsize=(12,5))
k1=sns.kdeplot(x=movies.Budgetmillions,y=movies.Audiencerating,ax=axes[0,0])
k2=sns.kdeplot(x=movies.Budgetmillions, y=movies.Criticrating,ax=axes[0,1])

k1.set(xlim=(-20,160))
k2.set(xlim=(-20,160))


z=sns.violinplot(data=movies[movies.Genre=='Drama'],x='Year',y='Criticrating',ax=axes[1,0])

k4=sns.kdeplot(x=movies.Criticrating,y=movies.Audiencerating,shade=True,shade_lowest=False,cmap='Greens',ax=axes[1,1])

k4b=sns.kdeplot(x=movies.Criticrating,y=movies.Audiencerating,cmap='Reds', ax=axes[1,1])

# %%
sns.set_style('white' , {'axes.facecolor':'black'})
f, axes=plt.subplots(2,2,figsize=(12,5))

k1= sns.kdeplot(x=movies.Budgetmillions, y=movies.Audiencerating,shade=True, shade_lowest=False, cmap='Greens_r' ,ax=axes[0,0])
k1b=sns.kdeplot(x=movies.Budgetmillions, y=movies.Audiencerating, ax=axes[0,0])

k2=sns.kdeplot(x=movies.Budgetmillions, y=movies.Criticrating, shade=True, shade_lowest=False, cmap='Blues', ax=axes[0,1])
k2b= sns.kdeplot(x=movies.Budgetmillions, y=movies.Criticrating,ax=axes[0,1])

z=sns.violinplot(data=movies[movies.Genre=='Drama'], x='Year', y='Criticrating', ax=axes[1,0])

k4=sns.kdeplot(x=movies.Criticrating, y=movies.Audiencerating, shade=True, shade_lowest=False, cmap='Greens', ax=axes[1,1])
k4b=sns.kdeplot(x=movies.Criticrating, y=movies.Audiencerating, ax=axes[1,1])
